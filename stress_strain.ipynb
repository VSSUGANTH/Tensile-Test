# %%
Time (sec )	Force (N )	Stroke (mm )	Stress (N/mm2 )	Strain (% )  # header for excel
# Out:
#   Input In [23]
#     Time (sec )	Force (N )	Stroke (mm )	Stress (N/mm2 )	Strain (% )  # header for excel
#                	^
# SyntaxError: invalid syntax

# %% [markdown]
# # sisal with epoxy stress strain curve

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pandas as pd

#load the  files 1
specimen1_df = pd.read_csv("s1.csv")
specimen1_df.head()
#load the  files 2
specimen2_df = pd.read_csv("s2.csv")
specimen2_df.head()
#load the  files 3
specimen3_df = pd.read_csv("s3.csv")
specimen3_df.head()
#load the  files 3
specimen4_df = pd.read_csv("s4.csv")
specimen4_df.head()
#load the  files 3
specimen5_df = pd.read_csv("s5.csv")
specimen5_df.head()

#load the  files 3
specimen6_df = pd.read_csv("s6.csv")
specimen6_df.head()

# #load the  files 3
# specimen7_df = pd.read_csv("s7.csv")
# specimen7_df.head()




#FINDING MAX AND MIN
p=specimen1_df['Tensile stress'].max()
q=specimen2_df['Tensile stress'].max()
r=specimen3_df['Tensile stress'].max()
s=specimen4_df['Tensile stress'].max()
t=specimen5_df['Tensile stress'].max()
u=specimen6_df['Tensile stress'].max()
# v=specimen7_df['Tensile stress'].max()


print("the Max1",p)
print("\n the Max2",q)
print("\n the Max3",r)
print("\nthe Max4",s)
print("\n the Max5",t)
print("\n the Max6",u)
# print("\n the Max7",v)

#loading

strain1=specimen1_df['Strain 1']
stress1=specimen1_df['Tensile stress']

strain2=specimen2_df['Strain 1']
stress2=specimen2_df['Tensile stress']

strain3=specimen3_df['Strain 1']
stress3=specimen3_df['Tensile stress']

strain4=specimen4_df['Strain 1']
stress4=specimen4_df['Tensile stress']

strain5=specimen5_df['Strain 1']
stress5=specimen5_df['Tensile stress']

strain6=specimen6_df['Strain 1']
stress6=specimen6_df['Tensile stress']

# strain7=specimen7_df['Strain 1']
# stress7=specimen7_df['Tensile stress']





plt.plot(strain1,stress1,strain2,stress2,strain3,stress3,strain4,stress4,strain5,stress5,strain6,stress6)
plt.xlabel('Strain (mm/mm)')
plt.ylabel('Stress (MPa)')
plt.title('Stress Strain Curve of sisal - epoxy in tension')

plt.legend(['s_1 ', 's_2','s_3','s_4','s_5','s_6'])

plt.savefig('stress-strain_curve combined.jpg', dpi=300, bbox_inches='tight') 
plt.show()
# Out:
# the Max1 61.40053
#
#  the Max2 72.18288
#
#  the Max3 34.55075
#
# the Max4 37.849
#
#  the Max5 59.81299
#
#  the Max6 57.37053

# %% [markdown]
# # sisal with epoxy Load vs Displacement

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pandas as pd

#load the  files 1
specimen1_df = pd.read_csv("s1.csv")
specimen1_df.head()
#load the  files 2
specimen2_df = pd.read_csv("s2.csv")
specimen2_df.head()
#load the  files 3
specimen3_df = pd.read_csv("s3.csv")
specimen3_df.head()
#load the  files 3
specimen4_df = pd.read_csv("s4.csv")
specimen4_df.head()
#load the  files 3
specimen5_df = pd.read_csv("s5.csv")
specimen5_df.head()

#load the  files 3
specimen6_df = pd.read_csv("s6.csv")
specimen6_df.head()

# #load the  files 3
# specimen7_df = pd.read_csv("s7.csv")
# specimen7_df.head()




#FINDING MAX AND MIN
p=specimen1_df['Load'].max()
q=specimen2_df['Load'].max()
r=specimen3_df['Load'].max()
s=specimen4_df['Load'].max()
t=specimen5_df['Load'].max()
u=specimen6_df['Load'].max()
# v=specimen7_df['Load'].max()


print("\n the Max1",p)
print("\n the Max2",q)
print("\n the Max3",r)
print("\n the Max4",s)
print("\n the Max5",t)
print("\n the Max6",u)
# print("\n the Max7",v)

#loading

strain1=specimen1_df['Extension']
stress1=specimen1_df['Load']

strain2=specimen2_df['Extension']
stress2=specimen2_df['Load']

strain3=specimen3_df['Extension']
stress3=specimen3_df['Load']

strain4=specimen4_df['Extension']
stress4=specimen4_df['Load']

strain5=specimen5_df['Extension']
stress5=specimen5_df['Load']

strain6=specimen6_df['Extension']
stress6=specimen6_df['Load']

# strain7=specimen7_df['Extension']
# stress7=specimen7_df['Load']




plt.plot(strain1,stress1,strain2,stress2,strain3,stress3,strain4,stress4,strain5,stress5,strain6,stress6)
plt.xlabel('Displacement (mm)')
plt.ylabel('Load (N)')
plt.title('Load vs Displacement')

plt.legend(['s_1 ', 's_2','s_3','s_4','s_5','s_6'])

plt.savefig('Load vs Displacement combined.jpg', dpi=300, bbox_inches='tight') 
plt.show()
# Out:
#  the Max1 4605.04
#
#  the Max2 5413.72
#
#  the Max3 3455.07
#
#  the Max4 3784.9
#
#  the Max5 4485.97
#
#  the Max6 4302.79

# %% [markdown]
# # stress vs strain new code

# %%
import pandas as pd
files = [1, 2, 3, 4,5, 6]

filepath = 'C:/Users/IIITDM-MECH DEPT/Desktop/10-10-2022 BANANA, SISAL/SISAL/PROCESSED/python/s'
for i in files:
    df_name = 's' + str(i)
    df_name= pd.read_csv(filepath+str(i)+'.csv')
#     print(df_name);
    p=df_name['Tensile stress'].max()
    print('the Max:',p)
    #loading
    strain1=df_name['Strain 1']
    stress1=df_name['Tensile stress']
    #plt.figure()

    plt.plot(strain1,stress1)
    plt.xlabel('Strain (mm/mm)')
    plt.ylabel('Stress (MPa)')
    plt.title('Stress Strain Curve of sisal - epoxy in tension')
    legend='s_'+str(i)
    plt.legend([legend])
    #plt.legend(['s_1 ', 's_2','s_3','s_4','s_5','s_6'])
    plt.savefig('stress-strain_curve'+str(i)+'.jpg', dpi=300, bbox_inches='tight') 
    plt.show()
# Out:
# the Max: 61.40053
# the Max: 72.18288
# the Max: 34.55075
# the Max: 37.849
# the Max: 59.81299
# the Max: 57.37053

# %% [markdown]
# # Load vs Displacement new code

# %%
import pandas as pd
files = [1, 2, 3, 4,5, 6]

filepath = 'C:/Users/IIITDM-MECH DEPT/Desktop/10-10-2022 BANANA, SISAL/SISAL/PROCESSED/python/s'
for i in files:
    df_name = 's' + str(i)
    df_name= pd.read_csv(filepath+str(i)+'.csv')
#     print(df_name);
    p=df_name['Load'].max()
    print("the Max:",p)
    #loading
    strain1=df_name['Extension']
    stress1=df_name['Load']
    plt.figure()
    plt.plot(strain1,stress1)
    plt.xlabel('Displacement (mm)')
    plt.ylabel('Load (N)')
    plt.title('Load vs Displacement')
    legend='s_'+str(i)
    plt.legend([legend])
    plt.savefig('Load vs Displacement'+str(i)+'.jpg', dpi=300, bbox_inches='tight') 
    plt.show()
# Out:
# the Max: 4605.04
# the Max: 5413.72
# the Max: 3455.07
# the Max: 3784.9
# the Max: 4485.97
# the Max: 4302.79
